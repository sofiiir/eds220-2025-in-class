# %% [markdown]
# # Functions
#
# ## What are functions?
#
# Functions are reusable blocks of code that perform a specific task. They help streamline your code by allowing you to avoid repetition, improve readability, and make maintenance easier.
#
# The general syntax for defining a function is the following:
#
# ```python
# def function_name(parameter_1, ..., parameter_n):
#     """Docstring"""
#     <body of the function>
#     return value  # Depending on the function
# ```

# %%
# Example 1: one-line docstring, no parameters, no return value
def greet():
    """Print a greeting message."""
    print("Hello, welcome to the class!")

# %%
# Example 2: multi-line docstring, parameters, and return value
def calculate_area(radius):
    """
    Calculate the area of a circle given its radius.
    
    Args:
        radius (float): The radius of the circle.
        
    Returns:
        float: The area of the circle, calculated as π * radius^2.
    """
    area = 3.14159 * radius ** 2
    return area

# %%
for radius in [1,2,3]:
    area = calculate_area(radius)
    print(f"The area of a circle with radius {radius} is {area:.3f}")
# Out:
# The area of a circle with radius 1 is 3.142
# The area of a circle with radius 2 is 12.566
# The area of a circle with radius 3 is 28.274

# %% [markdown]
# ## Data loading and preparation
#
# We'll practice creating functions using the same datasets from last week.

# %%
import os
import pandas as pd

import geopandas as gpd
import matplotlib.pyplot as plt

# Display all columns when looking at dataframes
pd.set_option("display.max.columns", None)

# --------------------------------------------------
# Import power plants data
URL = 'https://raw.githubusercontent.com/carmengg/eds-220-book/refs/heads/main/data/power_plants_epsg4269.csv'
power_plants = pd.read_csv(URL)
power_plants = power_plants.drop(columns='Unnamed: 0') # Drop first column

# Import states data
fp = os.path.join('data','tl_2022_us_state','tl_2022_us_state.shp')
states = gpd.read_file(fp)
states.columns = states.columns.str.lower()

# --------------------------------------------------
# Create geometry column for power plants
points = gpd.points_from_xy(power_plants.longitude,
                            power_plants.latitude)

# Convert power plants DataFrame to GeoDataFrame
power_plants = gpd.GeoDataFrame(power_plants,      # Data
                                geometry=points,   # Specify geometry column
                                crs='EPSG:4269'    # Specify CRS
                                )

# %% [markdown]
# ## Exercise: CA top power plant sources map
#
# Last week we solved the followinge exercise to use a `for` with a `zip` to create subplots of the top 3 power plant sources in California.

# %%
# Select CA power plants and boundary
ca_power_plants = power_plants[power_plants['state'] == 'California']
ca_boundary = states[states['name'] == 'California']

# CA top 3 power sources were previously given
ca_top_sources = ['solar', 'natural gas', 'hydroelectric']

# Create subplots for each top source in a single figure
fig, ax = plt.subplots(figsize=(12,6), nrows=1, ncols=3)
for axis, source in zip(ax, ca_top_sources):   # Iterate over subplots and energy sources

    axis.set_title(source)
    axis.axis('off')

    ca_boundary.plot(ax=axis,
                     color='none')
    
    # Subset power plants by source and plot
    source_subset = ca_power_plants[ca_power_plants['primsource'] == source]
    source_subset.plot(ax=axis,
                    markersize=5,
                    alpha=0.5)

plt.suptitle(f"Top 3 energy sources for electric power plants in California")    
plt.show()

# %% [markdown]
# ## Steps to create a function
#
# My recommended steps for writing a function:
#
# 1. Solve the problem for a specific example
# 2. Identify which parts of the code need to be generalized and update these parts
# 3. Wrap this into a function
# 4. Add additional parameters or assert statements
# 5. Test function
# 6. Add a docstring
#
# Example: we want to obtain the top 3 power sources for any state progamatically as a function
#
# ### Step 1: Solve for a specific examples
#
# Example: solve this for CA

# %%
state_power_plants = power_plants[power_plants['state']== 'California']
top_sources = (state_power_plants['primsource']
               .value_counts()
               .index[:3]
               .to_list())
top_sources
# Out:
# ['solar', 'natural gas', 'hydroelectric']

# %% [markdown]
# ## Step 2: Identify which parts of the code need to be generalized and update these parts

# %%
state = 'California'
state_power_plants = power_plants[power_plants['state']== state]
top_sources = (state_power_plants['primsource']
               .value_counts()
               .index[:3]
               .to_list())
top_sources
# Out:
# ['solar', 'natural gas', 'hydroelectric']

# %% [markdown]
# ### Step 3: Define the function
#
# and
#
# ### Step 4: Adjust your parameters

# %%
def top3_sources(state, power_plants):
    state_power_plants = power_plants[power_plants['state']== state]
    top_sources = (state_power_plants['primsource']
                .value_counts()
                .index[:3]
                .to_list())
    return top_sources

# %%
top3_sources('Alaska', power_plants)
# Out:
# ['petroleum', 'hydroelectric', 'natural gas']

# %% [markdown]
# ### Example
#
# Create a function that will produce a plot given a list of primary sources and a state name. (Recreate a prvious plot for any state.)
#
# ### Step 1: Solve an example

# %%
# Select CA power plants and boundary
ca_power_plants = power_plants[power_plants['state'] == 'California']
ca_boundary = states[states['name'] == 'California']

# CA top 3 power sources were previously given
ca_top_sources = top3_sources('California', power_plants)

# Create subplots for each top source in a single figure
fig, ax = plt.subplots(figsize=(12,6), nrows=1, ncols=3)
for axis, source in zip(ax, ca_top_sources):   # Iterate over subplots and energy sources

    axis.set_title(source)
    axis.axis('off')

    ca_boundary.plot(ax=axis,
                     color='none')
    
    # Subset power plants by source and plot
    source_subset = ca_power_plants[ca_power_plants['primsource'] == source]
    source_subset.plot(ax=axis,
                    markersize=5,
                    alpha=0.5)

plt.suptitle(f"Top 3 energy sources for electric power plants in California")    
plt.show()

# %% [markdown]
# ### Step 2: Which parts of the code need to be generalized

# %%
def plot_top3_power_sources(state_name, power_plants, states):
    # Select state power plants and boundary
    state_power_plants = power_plants[power_plants['state'] == state_name]
    state_boundary = states[states['name'] == state_name]
    # State top 3 power sources were previously given
    state_top_sources = ['solar', 'natural gas', 'hydroelectric']
    # Create subplots for each top source in a single figure
    fig, ax = plt.subplots(figsize=(12,6), nrows=1, ncols=3)
    for axis, source in zip(ax, state_top_sources):   # Iterate over subplots and energy sources
        axis.set_title(source)
        axis.axis('off')
        state_boundary.plot(ax=axis,
                        color='none')
    # Subset power plants by source and plot
        source_subset = state_power_plants[state_power_plants['primsource'] == source]
        source_subset.plot(ax=axis,
                        markersize=5,
                        alpha=0.5)
    plt.suptitle(f"Top 3 energy sources for electric power plants in {state}")
    plt.show()

# %%
plot_top3_power_sources('New York', power_plants, states)

# %% [markdown]
# Exercise 1
#
# Create a function called power_source_counts that, given a power source, returns a Series with the counts of power plants by state that use that source.
#
# Follow the steps:
#
# solve the problem for a specific example (e.g., ‘wind’)
# identify which parts of the code need to be generalized and update these parts
# wrap this into a function
# add additional parameters or assert statements if needed

# %%
primsource_power_source = power_plants[power_plants['primsource'] == 'solar']

power_source_counts = primsource_power_source.groupby('state').primsource.value_counts()

power_source_counts
# Out:
# state                 primsource
# Alabama               solar           9
# Arizona               solar          88
# Arkansas              solar          21
# California            solar         766
# Colorado              solar         129
# Connecticut           solar          59
# Delaware              solar          13
# District of Columbia  solar           9
# Florida               solar         137
# Georgia               solar         124
# Hawaii                solar          28
# Idaho                 solar          10
# Illinois              solar         133
# Indiana               solar          91
# Iowa                  solar          15
# Kansas                solar          11
# Kentucky              solar           8
# Louisiana             solar           7
# Maine                 solar          37
# Maryland              solar         125
# Massachusetts         solar         467
# Michigan              solar          46
# Minnesota             solar         462
# Mississippi           solar           9
# Missouri              solar          24
# Montana               solar           7
# Nebraska              solar          12
# Nevada                solar          47
# New Hampshire         solar           1
# New Jersey            solar         279
# New Mexico            solar          76
# New York              solar         396
# North Carolina        solar         728
# Ohio                  solar          35
# Oklahoma              solar          10
# Oregon                solar         113
# Pennsylvania          solar          42
# Puerto Rico           solar          16
# Rhode Island          solar          55
# South Carolina        solar         106
# South Dakota          solar           1
# Tennessee             solar          25
# Texas                 solar         126
# Utah                  solar          41
# Vermont               solar          49
# Virginia              solar          71
# Washington            solar           6
# Wisconsin             solar          43
# Wyoming               solar           1
# Name: count, dtype: int64

# %%
def power_source_counts(power_source, power_plants):

    primsource_power_source = power_plants[power_plants['primsource'] == power_source]

    power_source_counts = primsource_power_source.groupby('state').count()


    return power_source_counts

# %%
power_source_counts('solar', power_plants)
# Out:
#                       objectid  plant_code  plant_name  utility_id  \
# state
# Alabama                      9           9           9           9
# Arizona                     88          88          88          88
# Arkansas                    21          21          21          21
# California                 766         766         766         766
# Colorado                   129         129         129         129
# Connecticut                 59          59          59          59
# Delaware                    13          13          13          13
# District of Columbia         9           9           9           9
# Florida                    137         137         137         137
# Georgia                    124         124         124         124
# Hawaii                      28          28          28          28
# Idaho                       10          10          10          10
# Illinois                   133         133         133         133
# Indiana                     91          91          91          91
# Iowa                        15          15          15          15
# Kansas                      11          11          11          11
# Kentucky                     8           8           8           8
# Louisiana                    7           7           7           7
# Maine                       37          37          37          37
# Maryland                   125         125         125         125
# Massachusetts              467         467         467         467
# Michigan                    46          46          46          46
# Minnesota                  462         462         462         462
# Mississippi                  9           9           9           9
# Missouri                    24          24          24          24
# Montana                      7           7           7           7
# Nebraska                    12          12          12          12
# Nevada                      47          47          47          47
# New Hampshire                1           1           1           1
# New Jersey                 279         279         279         279
# New Mexico                  76          76          76          76
# New York                   396         396         396         396
# North Carolina             728         728         728         728
# Ohio                        35          35          35          35
# Oklahoma                    10          10          10          10
# Oregon                     113         113         113         113
# Pennsylvania                42          42          42          42
# Puerto Rico                 16          16          16          16
# Rhode Island                55          55          55          55
# South Carolina             106         106         106         106
# South Dakota                 1           1           1           1
# Tennessee                   25          25          25          25
# Texas                      126         126         126         126
# Utah                        41          41          41          41
# Vermont                     49          49          49          49
# Virginia                    71          71          71          71
# Washington                   6           6           6           6
# Wisconsin                   43          43          43          43
# Wyoming                      1           1           1           1
#
#                       utility_name  sector_name  street_address  city  county  \
# state
# Alabama                          9            9               9     9       9
# Arizona                         88           88              88    88      88
# Arkansas                        21           21              21    21      21
# California                     766          766             764   765     765
# Colorado                       129          129             129   129     129
# Connecticut                     59           59              59    59      59
# Delaware                        13           13              13    13      13
# District of Columbia             9            9               8     8       8
# Florida                        137          137             137   137     137
# Georgia                        124          124             124   124     124
# Hawaii                          28           28              28    28      28
# Idaho                           10           10              10    10      10
# Illinois                       133          133             133   133     133
# Indiana                         91           91              91    91      91
# Iowa                            15           15              15    15      15
# Kansas                          11           11              11    11      11
# Kentucky                         8            8               8     8       8
# Louisiana                        7            7               7     7       7
# Maine                           37           37              37    37      37
# Maryland                       125          125             125   125     125
# Massachusetts                  467          467             467   467     467
# Michigan                        46           46              44    46      46
# Minnesota                      462          462             462   462     462
# Mississippi                      9            9               9     9       9
# Missouri                        24           24              24    24      24
# Montana                          7            7               7     7       7
# Nebraska                        12           12              12    12      12
# Nevada                          47           47              47    47      47
# New Hampshire                    1            1               1     1       1
# New Jersey                     279          279             279   279     279
# New Mexico                      76           76              76    76      76
# New York                       396          396             394   395     395
# North Carolina                 728          728             716   716     716
# Ohio                            35           35              35    35      35
# Oklahoma                        10           10              10    10      10
# Oregon                         113          113             113   113     113
# Pennsylvania                    42           42              41    41      41
# Puerto Rico                     16           16              16    16      16
# Rhode Island                    55           55              55    55      55
# South Carolina                 106          106             105   105     105
# South Dakota                     1            1               1     1       1
# Tennessee                       25           25              25    25      25
# Texas                          126          126             126   126     126
# Utah                            41           41              41    41      41
# Vermont                         49           49              49    49      49
# Virginia                        71           71              71    71      71
# Washington                       6            6               6     6       6
# Wisconsin                       43           43              43    43      43
# Wyoming                          1            1               1     1       1
#
#                       zip  primsource  source_desc  tech_desc  install_mw  \
# state
# Alabama                 9           9            9          9           9
# Arizona                88          88           88         88          88
# Arkansas               21          21           21         21          21
# California            765         766          766        766         766
# Colorado              129         129          129        129         129
# Connecticut            59          59           59         59          59
# Delaware               13          13           13         13          13
# District of Columbia    8           9            9          9           9
# Florida               137         137          137        137         137
# Georgia               124         124          124        124         124
# Hawaii                 28          28           28         28          28
# Idaho                  10          10           10         10          10
# Illinois              133         133          133        133         133
# Indiana                91          91           91         91          91
# Iowa                   15          15           15         15          15
# Kansas                 11          11           11         11          11
# Kentucky                8           8            8          8           8
# Louisiana               7           7            7          7           7
# Maine                  37          37           37         37          37
# Maryland              125         125          125        125         125
# Massachusetts         467         467          467        467         467
# Michigan               46          46           46         46          46
# Minnesota             462         462          462        462         462
# Mississippi             9           9            9          9           9
# Missouri               24          24           24         24          24
# Montana                 7           7            7          7           7
# Nebraska               12          12           12         12          12
# Nevada                 47          47           47         47          47
# New Hampshire           1           1            1          1           1
# New Jersey            279         279          279        279         279
# New Mexico             76          76           76         76          76
# New York              395         396          396        396         396
# North Carolina        716         728          728        728         728
# Ohio                   35          35           35         35          35
# Oklahoma               10          10           10         10          10
# Oregon                113         113          113        113         113
# Pennsylvania           41          42           42         42          42
# Puerto Rico            16          16           16         16          16
# Rhode Island           55          55           55         55          55
# South Carolina        105         106          106        106         106
# South Dakota            1           1            1          1           1
# Tennessee              25          25           25         25          25
# Texas                 126         126          126        126         126
# Utah                   41          41           41         41          41
# Vermont                49          49           49         49          49
# Virginia               71          71           71         71          71
# Washington              6           6            6          6           6
# Wisconsin              43          43           43         43          43
# Wyoming                 1           1            1          1           1
#
#                       total_mw  bat_mw  bio_mw  coal_mw  geo_mw  hydro_mw  \
# state
# Alabama                      9       1       0        0       0         0
# Arizona                     88       8       0        0       0         0
# Arkansas                    21       1       0        0       0         0
# California                 766      41       2        0       0         0
# Colorado                   129       2       0        0       0         0
# Connecticut                 59       2       0        0       0         0
# Delaware                    13       0       0        0       0         0
# District of Columbia         9       0       0        0       0         0
# Florida                    137       6       0        0       0         0
# Georgia                    124       3       0        0       0         0
# Hawaii                      28       7       0        0       0         0
# Idaho                       10       0       0        0       0         0
# Illinois                   133       0       0        0       0         0
# Indiana                     91       1       0        0       0         0
# Iowa                        15       0       0        0       0         0
# Kansas                      11       0       0        0       0         0
# Kentucky                     8       0       0        0       0         0
# Louisiana                    7       1       0        0       0         0
# Maine                       37       0       0        0       0         0
# Maryland                   125       1       0        0       0         0
# Massachusetts              467      76       0        0       0         0
# Michigan                    46       1       0        0       0         0
# Minnesota                  462       1       0        0       0         0
# Mississippi                  9       0       0        0       0         0
# Missouri                    24       0       0        0       0         0
# Montana                      7       0       0        0       0         0
# Nebraska                    12       3       0        0       0         0
# Nevada                      47       4       0        0       0         0
# New Hampshire                1       0       0        0       0         0
# New Jersey                 279       0       0        0       0         0
# New Mexico                  76       2       0        0       0         0
# New York                   396      21       0        0       0         0
# North Carolina             728       2       1        0       0         0
# Ohio                        35       0       0        0       0         0
# Oklahoma                    10       0       0        0       0         0
# Oregon                     113       0       0        0       0         0
# Pennsylvania                42       0       0        0       0         0
# Puerto Rico                 16       3       0        0       0         0
# Rhode Island                55       0       0        0       0         0
# South Carolina             106       1       0        0       0         0
# South Dakota                 1       0       0        0       0         0
# Tennessee                   25       0       0        0       0         0
# Texas                      126       5       0        0       0         0
# Utah                        41       0       0        0       0         0
# Vermont                     49       5       0        0       0         0
# Virginia                    71       0       0        0       0         0
# Washington                   6       1       0        0       0         0
# Wisconsin                   43       1       0        0       0         0
# Wyoming                      1       0       0        0       0         0
#
#                       hydrops_mw  ng_mw  nuclear_mw  crude_mw  solar_mw  \
# state
# Alabama                        0      0           0         0         9
# Arizona                        0      0           0         0        88
# Arkansas                       0      0           0         0        21
# California                     0      2           0         0       766
# Colorado                       0      0           0         0       129
# Connecticut                    0      1           0         0        59
# Delaware                       0      0           0         0        13
# District of Columbia           0      0           0         0         9
# Florida                        0      0           0         0       137
# Georgia                        0      1           0         0       124
# Hawaii                         0      0           0         0        28
# Idaho                          0      0           0         0        10
# Illinois                       0      0           0         0       133
# Indiana                        0      0           0         0        91
# Iowa                           0      0           0         0        15
# Kansas                         0      0           0         0        11
# Kentucky                       0      0           0         0         8
# Louisiana                      0      0           0         0         7
# Maine                          0      0           0         0        37
# Maryland                       0      1           0         0       125
# Massachusetts                  0      0           0         0       467
# Michigan                       0      0           0         0        46
# Minnesota                      0      0           0         0       462
# Mississippi                    0      0           0         0         9
# Missouri                       0      0           0         0        24
# Montana                        0      0           0         0         7
# Nebraska                       0      0           0         0        12
# Nevada                         0      0           0         0        47
# New Hampshire                  0      0           0         0         1
# New Jersey                     0      1           0         0       279
# New Mexico                     0      0           0         0        76
# New York                       0      0           0         0       396
# North Carolina                 0      0           0         0       728
# Ohio                           0      0           0         0        35
# Oklahoma                       0      0           0         0        10
# Oregon                         0      0           0         0       113
# Pennsylvania                   0      0           0         0        42
# Puerto Rico                    0      0           0         1        16
# Rhode Island                   0      0           0         0        55
# South Carolina                 0      1           0         1       106
# South Dakota                   0      0           0         0         1
# Tennessee                      0      0           0         0        25
# Texas                          0      0           0         0       126
# Utah                           0      0           0         0        41
# Vermont                        0      0           0         0        49
# Virginia                       0      0           0         0        71
# Washington                     0      0           0         0         6
# Wisconsin                      0      0           0         0        43
# Wyoming                        0      0           0         0         1
#
#                       wind_mw  other_mw  source  period  longitude  latitude  \
# state
# Alabama                     0         0       9       9          9         9
# Arizona                     1         0      88      88         88        88
# Arkansas                    0         0      21      21         21        21
# California                  0         0     766     766        766       766
# Colorado                    0         0     129     129        129       129
# Connecticut                 0         0      59      59         59        59
# Delaware                    0         0      13      13         13        13
# District of Columbia        0         0       9       9          9         9
# Florida                     0         0     137     137        137       137
# Georgia                     0         0     124     124        124       124
# Hawaii                      0         0      28      28         28        28
# Idaho                       0         0      10      10         10        10
# Illinois                    0         0     133     133        133       133
# Indiana                     0         0      91      91         91        91
# Iowa                        0         0      15      15         15        15
# Kansas                      0         0      11      11         11        11
# Kentucky                    0         0       8       8          8         8
# Louisiana                   0         0       7       7          7         7
# Maine                       0         0      37      37         37        37
# Maryland                    0         0     125     125        125       125
# Massachusetts               0         0     467     467        467       467
# Michigan                    0         0      46      46         46        46
# Minnesota                   0         0     462     462        462       462
# Mississippi                 0         0       9       9          9         9
# Missouri                    0         0      24      24         24        24
# Montana                     0         0       7       7          7         7
# Nebraska                    0         0      12      12         12        12
# Nevada                      0         0      47      47         47        47
# New Hampshire               0         0       1       1          1         1
# New Jersey                  0         0     279     279        279       279
# New Mexico                  0         0      76      76         76        76
# New York                    0         0     396     396        396       396
# North Carolina              0         0     728     728        728       728
# Ohio                        0         0      35      35         35        35
# Oklahoma                    0         0      10      10         10        10
# Oregon                      0         0     113     113        113       113
# Pennsylvania                0         0      42      42         42        42
# Puerto Rico                 1         0      16      16         16        16
# Rhode Island                0         0      55      55         55        55
# South Carolina              0         0     106     106        106       106
# South Dakota                0         0       1       1          1         1
# Tennessee                   0         0      25      25         25        25
# Texas                       0         0     126     126        126       126
# Utah                        0         0      41      41         41        41
# Vermont                     0         0      49      49         49        49
# Virginia                    0         0      71      71         71        71
# Washington                  0         0       6       6          6         6
# Wisconsin                   0         0      43      43         43        43
# Wyoming                     0         0       1       1          1         1
#
#                       geometry
# state
# Alabama                      9
# Arizona                     88
# Arkansas                    21
# California                 766
# Colorado                   129
# Connecticut                 59
# Delaware                    13
# District of Columbia         9
# Florida                    137
# Georgia                    124
# Hawaii                      28
# Idaho                       10
# Illinois                   133
# Indiana                     91
# Iowa                        15
# Kansas                      11
# Kentucky                     8
# Louisiana                    7
# Maine                       37
# Maryland                   125
# Massachusetts              467
# Michigan                    46
# Minnesota                  462
# Mississippi                  9
# Missouri                    24
# Montana                      7
# Nebraska                    12
# Nevada                      47
# New Hampshire                1
# New Jersey                 279
# New Mexico                  76
# New York                   396
# North Carolina             728
# Ohio                        35
# Oklahoma                    10
# Oregon                     113
# Pennsylvania                42
# Puerto Rico                 16
# Rhode Island                55
# South Carolina             106
# South Dakota                 1
# Tennessee                   25
# Texas                      126
# Utah                        41
# Vermont                     49
# Virginia                    71
# Washington                   6
# Wisconsin                   43
# Wyoming                      1

# %%
# Step 1: solve an example
top_states = power_plants[power_plants.primsource == 'wind'].state.value_counts()
top_states
# Out:
# state
# Texas             215
# Minnesota         122
# Iowa              121
# California        107
# Oklahoma           64
# Illinois           50
# Oregon             49
# Kansas             47
# North Dakota       39
# Nebraska           34
# Michigan           34
# Colorado           32
# New York           32
# Idaho              32
# New Mexico         29
# Pennsylvania       26
# Wyoming            25
# South Dakota       23
# Washington         23
# Ohio               22
# Massachusetts      20
# Indiana            20
# Maine              20
# Rhode Island       19
# Montana            19
# Missouri           14
# Wisconsin          12
# Hawaii              8
# West Virginia       8
# Arizona             6
# New Hampshire       5
# Utah                5
# Maryland            5
# Vermont             5
# Alaska              4
# Tennessee           2
# New Jersey          2
# Puerto Rico         2
# Delaware            1
# Nevada              1
# Virginia            1
# North Carolina      1
# Connecticut         1
# Name: count, dtype: int64

# %%
# Step 2: identify what needs to be generalized
source = 'wind'
top_states = power_plants[power_plants.primsource == source].state.value_counts()
top_states
# Out:
# state
# Texas             215
# Minnesota         122
# Iowa              121
# California        107
# Oklahoma           64
# Illinois           50
# Oregon             49
# Kansas             47
# North Dakota       39
# Nebraska           34
# Michigan           34
# Colorado           32
# New York           32
# Idaho              32
# New Mexico         29
# Pennsylvania       26
# Wyoming            25
# South Dakota       23
# Washington         23
# Ohio               22
# Massachusetts      20
# Indiana            20
# Maine              20
# Rhode Island       19
# Montana            19
# Missouri           14
# Wisconsin          12
# Hawaii              8
# West Virginia       8
# Arizona             6
# New Hampshire       5
# Utah                5
# Maryland            5
# Vermont             5
# Alaska              4
# Tennessee           2
# New Jersey          2
# Puerto Rico         2
# Delaware            1
# Nevada              1
# Virginia            1
# North Carolina      1
# Connecticut         1
# Name: count, dtype: int64

# %%
# Step 3&4: Wrap things in a function , add parameters

def power_source_counts(source, power_plants):
    top_states = power_plants[power_plants.primsource == source].state.value_counts()
    return top_states

# %%
power_source_counts('nuclear', power_plants)
# Out:
# state
# Illinois          6
# South Carolina    4
# Pennsylvania      4
# New York          3
# North Carolina    3
# New Jersey        2
# Texas             2
# Louisiana         2
# Virginia          2
# Alabama           2
# Minnesota         2
# Michigan          2
# Georgia           2
# Florida           2
# Tennessee         2
# Ohio              2
# California        1
# Missouri          1
# New Hampshire     1
# Nebraska          1
# Wisconsin         1
# Mississippi       1
# Maryland          1
# Arizona           1
# Connecticut       1
# Washington        1
# Kansas            1
# Arkansas          1
# Name: count, dtype: int64
